# %%
from qiskit import *
from qiskit.visualization import plot_histogram
from qiskit.tools.monitor import job_monitor

# %%
bell = QuantumCircuit(2,2)
bell.h(0)
bell.cx(0,1)
meas = QuantumCircuit(2,2)
meas.measure([0,1], [0,1])
backend = BasicAer.get_backend('qasm_simulator')
circ = bell.compose(meas)
result = backend.run(transpile(circ,backend),shots=1000).result()
counts = result.get_counts(circ)
print (counts)
# Out:
# {'00': 506, '11': 494}

# %%
second_result = backend.run(transpile(circ,backend), shots=1000).result()
second_counts = second_result.get_counts(circ)
legend = ['First execution', 'second execution']
plot_histogram([counts, second_counts], legend=legend)

# %%
plot_histogram([counts, second_counts], legend=legend, sort='desc', figsize=(8,10),
               color=['orange', 'green'], bar_labels=False)

# %%
from qiskit.visualization import plot_state_city,plot_bloch_multivector
from qiskit.visualization import plot_state_paulivec, plot_state_hinton
from qiskit.visualization import plot_state_qsphere

# %%
backend = BasicAer.get_backend('statevector_simulator')
result = backend.run(transpile(bell, backend)).result()
psi = result.get_statevector(bell)

# %%
plot_state_city(psi)

# %%
plot_state_paulivec(psi)

# %%
plot_bloch_multivector(psi)

# %%
plot_state_paulivec(psi, title="My Paulivec", color=['purple','orange','green'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9912/1959472841.py in <module>
# ----> 1 plot_state_paulivec(psi, title="My Paulivec", color=['purple','orange','green'])
#
# NameError: name 'plot_state_paulivec' is not defined

# %%
from qiskit.visualizationi import plot_bloch_vector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9912/2063805149.py in <module>
# ----> 1 from qiskit.visualizationi import plot_bloch_vector
#
# ModuleNotFoundError: No module named 'qiskit.visualizationi'

# %%
plot_bloch_vector([0,1,0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9912/534839534.py in <module>
# ----> 1 plot_bloch_vector([0,1,0])
#
# NameError: name 'plot_bloch_vector' is not defined

# %%
plot_bloch_vector([0,1,0], title='My Bloch Sphere')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9912/65540855.py in <module>
# ----> 1 plot_bloch_vector([0,1,0], title='My Bloch Sphere')
#
# NameError: name 'plot_bloch_vector' is not defined

# %%
plot_bloch_vector([0,1,0], title='My Bloch Sphere')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9912/65540855.py in <module>
# ----> 1 plot_bloch_vector([0,1,0], title='My Bloch Sphere')
#
# NameError: name 'plot_bloch_vector' is not defined

# %%
import matplotlib.pyplot as plt

# %%
import nump as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9912/1202007956.py in <module>
# ----> 1 import nump as np
#
# ModuleNotFoundError: No module named 'nump'

# %%
from math import pi

# %%
from qiskit import QuantumCircuit,ClassicalRegister, QuantumRegister, transpile
from qiskit.tools.visualization import circuit_drawer
from qiskit.quantum_info import state_fidelity
from qiskit import BasicAer

backend = BasicAer.get_backend('unitary_simulator')

# %%
q = QuantumRegister(1)

# %%
qc = QuantumCircuit(q)
qc.u(pi/2,pi/4,pi/8,q)
qc.draw()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13284/2573685665.py in <module>
# ----> 1 qc = QuantumCircuit(q)
#       2 qc.u(pi/2,pi/4,pi/8,q)
#       3 qc.draw()
#
# NameError: name 'QuantumCircuit' is not defined

# %%
job = backend.run(transpile(qc, backend))
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[ 0.707+0.j   , -0.653-0.271j],
#        [ 0.5  +0.5j  ,  0.271+0.653j]])

# %%
qc = QuantumCircuit(q)
qc.p(pi/2,q)
qc.draw()
# Out:
#     ┌────────┐
# q0: ┤ P(π/2) ├
#     └────────┘

# %%
job = backend.run(transpile(qc, backend))
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[1.+0.j, 0.+0.j],
#        [0.+0.j, 0.+1.j]])

# %%
qc = QuantumCircuit(q)
qc.id(q)
qc.draw()
# Out:
#     ┌───┐
# q0: ┤ I ├
#     └───┘

# %%
job = backend.run(transpile(qc, backend))
job.result().get_unitary(qc, decimals=3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9912/1544215966.py in <module>
# ----> 1 job = backend.run(transpile(qc, backend))
#       2 job.result().get_unitary(qc, decimals=3)
#
# ~\anaconda3\lib\site-packages\qiskit\compiler\transpiler.py in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target)
#     274
#     275     # Get transpile_args to configure the circuit transpilation job(s)
# --> 276     transpile_args = _parse_transpile_args(
#     277         circuits,
#     278         backend,
#
# ~\anaconda3\lib\site-packages\qiskit\compiler\transpiler.py in _parse_transpile_args(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, seed_transpiler, optimization_level, callback, output_name, timing_constraints, unitary_synthesis_method, unitary_synthesis_plugin_config, target)
#     538     seed_transpiler = _parse_seed_transpiler(seed_transpiler, num_circuits)
#     539     optimization_level = _parse_optimization_level(optimization_level, num_circuits)
# --> 540     output_name = _parse_output_name(output_name, circuits)
#     541     callback = _parse_callback(callback, num_circuits)
#     542     durations = _parse_instruction_durations(backend, instruction_durations, dt, circuits)
#
# ~\anaconda3\lib\site-packages\qiskit\compiler\transpiler.py in _parse_output_name(output_name, circuits)
#    1056             )
#    1057     else:
# -> 1058         return [circuit.name for circuit in circuits]
#    1059
#    1060
#
# ~\anaconda3\lib\site-packages\qiskit\compiler\transpiler.py in <listcomp>(.0)
#    1056             )
#    1057     else:
# -> 1058         return [circuit.name for circuit in circuits]
#    1059
#    1060
#
# AttributeError: 'BasicAerJob' object has no attribute 'name'

# %%
q = QuantumRegister(2)

# %%
qc = QuantumCircuit(q)
qc.cx(q[0],q[1])
qc.draw()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13284/2843934545.py in <module>
# ----> 1 qc = QuantumCircuit(q)
#       2 qc.cx(q[0],q[1])
#       3 qc.draw()
#
# NameError: name 'QuantumCircuit' is not defined
